png
# /kaggle/input/image-super-resolution/dataset/train/high_res/670.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/393.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/17.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/53.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/266.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/486.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/657.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/196.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/626.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/571.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/179.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/178.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/160.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/671.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/140.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/620.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/636.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/52.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/5.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/139.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/3.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/172.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/64.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/406.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/347.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/665.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/355.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/16.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/438.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/430.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/545.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/409.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/328.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/423.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/643.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/461.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/375.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/203.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/8.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/489.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/45.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/382.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/24.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/548.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/444.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/373.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/32.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/88.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/463.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/649.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/624.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/283.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/274.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/115.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/249.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/128.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/668.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/158.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/583.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/6.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/23.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/87.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/275.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/51.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/591.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/400.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/101.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/606.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/618.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/536.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/297.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/135.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/482.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/512.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/123.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/91.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/504.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/230.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/478.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/44.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/399.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/189.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/541.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/601.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/442.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/343.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/454.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/410.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/68.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/422.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/286.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/180.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/46.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/508.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/499.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/664.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/516.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/470.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/57.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/448.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/84.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/475.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/564.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/15.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/210.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/234.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/358.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/365.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/652.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/252.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/531.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/507.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/565.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/679.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/523.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/183.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/678.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/450.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/30.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/485.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/408.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/631.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/569.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/427.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/619.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/622.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/537.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/429.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/321.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/60.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/235.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/99.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/155.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/593.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/676.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/228.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/27.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/390.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/237.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/451.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/474.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/292.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/421.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/201.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/539.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/519.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/295.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/394.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/273.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/269.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/459.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/413.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/78.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/212.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/47.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/207.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/149.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/487.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/13.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/535.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/260.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/253.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/206.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/557.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/613.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/600.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/381.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/342.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/346.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/134.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/590.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/566.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/259.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/25.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/285.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/341.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/54.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/462.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/558.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/111.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/611.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/62.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/205.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/369.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/0.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/141.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/532.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/309.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/560.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/19.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/110.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/544.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/308.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/26.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/568.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/388.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/79.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/633.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/257.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/305.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/477.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/42.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/175.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/518.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/226.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/428.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/217.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/494.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/659.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/418.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/452.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/306.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/497.png
# /kaggle/input/image-super-resolution/dataset/train/high_res/304.png

# %%
import numpy as np
import os
import cv2
import tensorflow as tf
from tensorflow.keras import layers, models, Input
import matplotlib.pyplot as plt

# Residual Unit with two Conv layers, residual connection, and Batch Normalization
def residual_unit(input_tensor, filters, kernel_size=3):
    x = layers.Conv2D(filters, (kernel_size, kernel_size), padding='same', kernel_initializer='he_normal')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(filters, (kernel_size, kernel_size), padding='same', kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization()(x)
    return layers.Add()([input_tensor, x])  # Local residual connection

# Recursive Block (with shared weights among residual units)
def recursive_block(input_tensor, num_residual_units, filters):
    x = input_tensor
    for _ in range(num_residual_units):
        x = residual_unit(x, filters)
    return x

# DRRN Model
def DRRN(input_shape, num_recursive_blocks, num_residual_units, filters):
    inputs = Input(shape=input_shape)

    # Initial Conv Layer
    x = layers.Conv2D(filters, (3, 3), padding='same')(inputs)

    # Recursive blocks with residual connections
    for _ in range(num_recursive_blocks):
        x = recursive_block(x, num_residual_units, filters)

    # Output Conv Layer to reconstruct residual image
    x = layers.Conv2D(3, (3, 3), padding='same')(x)

    # Global Residual Learning (add the input LR image to the predicted residual)
    outputs = layers.Add()([inputs, x])

    # Build model
    model = models.Model(inputs, outputs)
    return model

# Function to extract 31x31 patches with a stride of 21 from a single image
def extract_patches(image, patch_size=31, stride=21):
    patches = []
    h, w, _ = image.shape
    for y in range(0, h - patch_size + 1, stride):
        for x in range(0, w - patch_size + 1, stride):
            patch = image[y:y + patch_size, x:x + patch_size]
            patches.append(patch)
    return np.array(patches)

# Function to load images from a directory and extract low-res and high-res patches
def load_and_extract_patches(low_res_dir, high_res_dir, patch_size=31, stride=21):
    low_res_patches = []
    high_res_patches = []

    # Assuming filenames are identical for both low-res and high-res images
    for file_name in os.listdir(low_res_dir):
        # Load low-resolution image
        low_res_image_path = os.path.join(low_res_dir, file_name)
        low_res_image = cv2.imread(low_res_image_path)
        
        # Load high-resolution image
        high_res_image_path = os.path.join(high_res_dir, file_name)
        high_res_image = cv2.imread(high_res_image_path)
        
        # Ensure both images have at least patch_size dimensions and are the same size
        if (low_res_image.shape[0] >= patch_size and low_res_image.shape[1] >= patch_size and
            high_res_image.shape == low_res_image.shape):
            
            # Extract patches from both low-res and high-res images
            low_res_patches.extend(extract_patches(low_res_image, patch_size, stride))
            high_res_patches.extend(extract_patches(high_res_image, patch_size, stride))
    
    return np.array(low_res_patches), np.array(high_res_patches)

# Function to train and evaluate the model with different numbers of layers
def train_and_evaluate_drrn(num_residual_units_list, num_recursive_blocks, filters, input_shape, X_train, Y_train, epochs=5):
    train_loss_histories = []
    val_loss_histories = []
    
    for num_residual_units in num_residual_units_list:
        print(f"\nTraining DRRN model with {num_residual_units} residual units in each recurrent block...\n")
        
        # Build the DRRN model
        drrn_model = DRRN(input_shape, num_recursive_blocks, num_residual_units, filters)
        
        # Compile the model with a lower learning rate and gradient clipping
        optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4, clipvalue=1.0)
        drrn_model.compile(optimizer=optimizer, loss='mse', metrics=['accuracy'])
        
        # Train the model
        history = drrn_model.fit(X_train, Y_train, batch_size=128, epochs=epochs, validation_split=0.1, verbose=1)
        
        # Save the loss history for plotting
        train_loss_histories.append(history.history['loss'])
        val_loss_histories.append(history.history['val_loss'])
        
        # Save the model for future use (optional)
        drrn_model.save(f"drrn_model_{num_residual_units}_residual_units.h5")
    
    return train_loss_histories, val_loss_histories

# Plotting function to visualize the effect of different numbers of residual units on log scale
def plot_loss_histories(num_residual_units_list, train_loss_histories, val_loss_histories):
    plt.figure(figsize=(12, 6))
    
    for i, num_residual_units in enumerate(num_residual_units_list):
        plt.plot(np.log10(train_loss_histories[i]), label=f'Train Loss (Residual Units: {num_residual_units})')
        plt.plot(np.log10(val_loss_histories[i]), label=f'Val Loss (Residual Units: {num_residual_units})')
    
    plt.title('Effect of Residual Units on Training and Validation Loss (Log Scale)')
    plt.xlabel('Epochs')
    plt.ylabel('Log Loss (MSE)')
    plt.legend()
    plt.grid(True)
    plt.show()

# Define the paths to your low-resolution and high-resolution images
low_res_dir = "/kaggle/input/image-super-resolution/dataset/Raw Data/low_res"
high_res_dir = "/kaggle/input/image-super-resolution/dataset/Raw Data/high_res"

# Extract low-res and high-res patches
X_train, Y_train = load_and_extract_patches(low_res_dir, high_res_dir, patch_size=31, stride=21)

# Normalize the patches (if necessary)
X_train = X_train / 255.0  # Normalize low-res patches (input)
Y_train = Y_train / 255.0  # Normalize high-res patches (target)

# Reshape the data for model input
X_train = X_train.reshape(-1, 31, 31, 3)  # Low-res patches
Y_train = Y_train.reshape(-1, 31, 31, 3)  # High-res patches

print(f"Extracted {X_train.shape[0]} patches of size 31x31 from the dataset.")

# Define the input shape (LR image), number of recursive blocks, and filters
input_shape = (31, 31, 3)  # (height, width, channels)
num_recursive_blocks = 3  # Number of recursive blocks
filters = 64              # Number of filters in Conv layers

# Define the number of residual units (layers) to test in the recurrent block
num_residual_units_list = [4, 6, 8, 10, 12]  

# Train and evaluate the model for different numbers of residual units
train_loss_histories, val_loss_histories = train_and_evaluate_drrn(
    num_residual_units_list, num_recursive_blocks, filters, input_shape, X_train, Y_train, epochs=15
)

# Plot the results
plot_loss_histories(num_residual_units_list, train_loss_histories, val_loss_histories)
# Out:
# Extracted 103455 patches of size 31x31 from the dataset.
#
# Training DRRN model with 4 residual units in each recurrent block...
#
# Epoch 1/15
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1727759095.262435     100 service.cc:145] XLA service 0x79d4d406e250 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1727759095.262501     100 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#   1/728 ━━━━━━━━━━━━━━━━━━━━ 4:23:08 22s/step - accuracy: 0.3800 - loss: 20.6838
# I0000 00:00:1727759102.914446     100 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 728/728 ━━━━━━━━━━━━━━━━━━━━ 98s 105ms/step - accuracy: 0.3979 - loss: 1.2633 - val_accuracy: 0.4924 - val_loss: 0.0629
# Epoch 2/15
# 728/728 ━━━━━━━━━━━━━━━━━━━━ 69s 94ms/step - accuracy: 0.4767 - loss: 0.0433 - val_accuracy: 0.5463 - val_loss: 0.0233
# Epoch 3/15
# 728/728 ━━━━━━━━━━━━━━━━━━━━ 69s 94ms/step - accuracy: 0.5167 - loss: 0.0219 - val_accuracy: 0.5602 - val_loss: 0.0172
# Epoch 4/15
# 728/728 ━━━━━━━━━━━━━━━━━━━━ 69s 94ms/step - accuracy: 0.5464 - loss: 0.0146 - val_accuracy: 0.6297 - val_loss: 0.0105
# Epoch 5/15
# 728/728 ━━━━━━━━━━━━━━━━━━━━ 69s 94ms/step - accuracy: 0.5733 - loss: 0.0106 - val_accuracy: 0.5674 - val_loss: 0.0081
# Epoch 6/15
# 728/728 ━━━━━━━━━━━━━━━━━━━━ 69s 95ms/step - accuracy: 0.5972 - loss: 0.0080 - val_accuracy: 0.6458 - val_loss: 0.0058
# Epoch 7/15
# 728/728 ━━━━━━━━━━━━━━━━━━━━ 69s 95ms/step - accuracy: 0.6095 - loss: 0.0070 - val_accuracy: 0.6137 - val_loss: 0.0091
# Epoch 8/15
# 728/728 ━━━━━━━━━━━━━━━━━━━━ 69s 94ms/step - accuracy: 0.6246 - loss: 0.0061 - val_accuracy: 0.6770 - val_loss: 0.0042
# Epoch 9/15
# 728/728 ━━━━━━━━━━━━━━━━━━━━ 69s 94ms/step - accuracy: 0.6439 - loss: 0.0047 - val_accuracy: 0.6169 - val_loss: 0.0061
# Epoch 10/15
# 399/728 ━━━━━━━━━━━━━━━━━━━━ 30s 91ms/step - accuracy: 0.6414 - loss: 0.0047
